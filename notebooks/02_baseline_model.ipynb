# %% [markdown]
# # LithoLens Baseline Model
#
# Use this notebook to run and inspect the baseline model. Prefer calling `litholens.pipeline.run_training_pipeline` instead of duplicating pipeline code.
