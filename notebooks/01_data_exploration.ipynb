# %% [markdown]
# # LithoLens Data Exploration
#
# Use this notebook to inspect FORCE-style well-log coverage, missingness, lithology balance, and per-well curve availability. Keep reusable logic in `src/litholens/`.
